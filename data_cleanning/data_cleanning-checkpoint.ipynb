# %%
import pandas as pd

# %%
df = pd.read_csv('E:/unevercity/New folder/cs-4/a/data_mining.csv',delimiter=';')

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 57   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 58  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 59  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 60    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 61   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0    58.6   29  13   7   626   6
# ...

# %%
df=df.rename(columns={'NO':'NOT_outs','HS':'Hight_InnsScore'})

# %%
df
# Out:
#                Player       Span  Mat  Inns  NOT_outs  Runs Hight_InnsScore  \
# 0    DG Bradman (AUS)  1928-1948   52    80        10  6996             334
# 1      HC Brook (ENG)  2022-2023   12    20         1  1181             186
# 2      AC Voges (AUS)  2015-2016   20    31         7  1485            269*
# 3     RG Pollock (SA)  1963-1970   23    41         4  2256             274
# 4     GA Headley (WI)  1930-1954   22    40         4  2190            270*
# ..                ...        ...  ...   ...       ...   ...             ...
# 57   KD Walters (AUS)  1965-1981   74   125        14  5357             250
# 58  GC Smith (ICC/SA)  2002-2014  117   205        13  9265             277
# 59  WH Ponsford (AUS)  1924-1934   29    48         4  2122             266
# 60    SJ McCabe (AUS)  1930-1938   39    62         5  2748             232
# 61   DR Jardine (ENG)  1928-1934   22    33         6  1296             127
#
#       Ave     BF     SR  100  50   0    4s  6s
# ...

# %%
df.head()
# Out:
#              Player       Span  Mat  Inns  NOT_outs  Runs Hight_InnsScore  \
# 0  DG Bradman (AUS)  1928-1948   52    80        10  6996             334
# 1    HC Brook (ENG)  2022-2023   12    20         1  1181             186
# 2    AC Voges (AUS)  2015-2016   20    31         7  1485            269*
# 3   RG Pollock (SA)  1963-1970   23    41         4  2256             274
# 4   GA Headley (WI)  1930-1954   22    40         4  2190            270*
#
#      Ave     BF     SR  100  50  0   4s  6s
# 0  99.94  9800+   58.6   29  13  7  626   6
# 1  62.15   1287  91.76    4   7  1  141  23
# 2  61.87   2667  55.68    5   4  2  186   5
# 3  60.97  1707+  54.48    7  11  1  246  11
# 4  60.83   416+     56   10   5  2  104   1

# %%
df.isnull().any()
# Out:
# Player             False
# Span               False
# Mat                False
# Inns               False
# NOT_outs           False
# Runs               False
# Hight_InnsScore    False
# Ave                False
# BF                 False
# SR                 False
# 100                False
# 50                 False
# 0                  False
# 4s                 False
# 6s                 False
# dtype: bool

# %%
 df[df['BF'].isna()==1]
# Out:
# Empty DataFrame
# Columns: [Player, Span, Mat, Inns, NOT_outs, Runs, Hight_InnsScore, Ave, BF, SR, 100, 50, 0, 4s, 6s]
# Index: []

# %%
df['BF']=df['BF'].fillna(0)

# %%
df['SR']=df['SR'].fillna(0)

# %%
df[df['Player']=='ED Weekes (WI)']
# Out:
#            Player       Span  Mat  Inns  NOT_outs  Runs Hight_InnsScore  \
# 8  ED Weekes (WI)  1948-1958   48    81         5  4455             207
#
#      Ave BF SR  100  50  0   4s  6s
# 8  58.61  -  -   15  19  6  258   2

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 57    False
# 58    False
# 59    False
# 60    False
# 61    False
# Length: 62, dtype: bool

# %%
df['BF']=df['BF'].fillna(1)

# %%
df[df['BF'].duplicated()==1]
# Out:
#                   Player       Span  Mat  Inns  NOT_outs  Runs  \
# 14       CL Walcott (WI)  1948-1960   44    74         7  3798
# 54  Hon.FS Jackson (ENG)  1893-1905   20    33         4  1415
#
#    Hight_InnsScore    Ave BF SR  100  50  0   4s  6s
# 14             220  56.68  -  -   15  14  1  107  11
# 54            144*  48.79  -  -    5   6  3   51   0

# %%
df[df['BF'].isin(['CL Walcott (WI)','Hon.FS Jackson (ENG)'])]
# Out:
# Empty DataFrame
# Columns: [Player, Span, Mat, Inns, NOT_outs, Runs, Hight_InnsScore, Ave, BF, SR, 100, 50, 0, 4s, 6s]
# Index: []

# %%
df['Span']
# Out:
# 0     1928-1948
# 1     2022-2023
# 2     2015-2016
# 3     1963-1970
# 4     1930-1954
#         ...
# 57    1965-1981
# 58    2002-2014
# 59    1924-1934
# 60    1930-1938
# 61    1928-1934
# Name: Span, Length: 62, dtype: object

# %%
df['Span'].str.split(pat='-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 57    [1965, 1981]
# 58    [2002, 2014]
# 59    [1924, 1934]
# 60    [1930, 1938]
# 61    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
df['Span'].str.split(pat='-').str[1]
# Out:
# 0     1948
# 1     2023
# 2     2016
# 3     1970
# 4     1954
#       ...
# 57    1981
# 58    2014
# 59    1934
# 60    1938
# 61    1934
# Name: Span, Length: 62, dtype: object

# %%
df['Rookie_Year']=df['Span'].str.split(pat='-').str[0]

# %%
df['Final_Year']=df['Span'].str.split(pat='-').str[1]

# %%
df = df.drop(['Span'],axis=1)

# %%
df['dopist']=df['SR']

# %%
df
# Out:
#                Player  Mat  Inns  NOT_outs  Runs Hight_InnsScore    Ave  \
# 0    DG Bradman (AUS)   52    80        10  6996             334  99.94
# 1      HC Brook (ENG)   12    20         1  1181             186  62.15
# 2      AC Voges (AUS)   20    31         7  1485            269*  61.87
# 3     RG Pollock (SA)   23    41         4  2256             274  60.97
# 4     GA Headley (WI)   22    40         4  2190            270*  60.83
# ..                ...  ...   ...       ...   ...             ...    ...
# 57   KD Walters (AUS)   74   125        14  5357             250  48.26
# 58  GC Smith (ICC/SA)  117   205        13  9265             277  48.25
# 59  WH Ponsford (AUS)   29    48         4  2122             266  48.22
# 60    SJ McCabe (AUS)   39    62         5  2748             232  48.21
# 61   DR Jardine (ENG)   22    33         6  1296             127  48.00
#
#        BF     SR  100  50   0    4s  6s Rookie_Year Final_Year dopist
# ...

# %%
df['Player'].str.split(pat='(').str[1]
# Out:
# 0        AUS)
# 1        ENG)
# 2        AUS)
# 3         SA)
# 4         WI)
#        ...
# 57       AUS)
# 58    ICC/SA)
# 59       AUS)
# 60       AUS)
# 61       ENG)
# Name: Player, Length: 62, dtype: object

# %%
df['Country']=df['Player'].str.split(pat='(').str[1]

# %%
df['Country']=df['Country'].str.split(pat=')').str[0]

# %%
df['Country']=df['Country'].str.split(pat='(').str[1]

# %%
df['Country']
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
#       ..
# 57   NaN
# 58   NaN
# 59   NaN
# 60   NaN
# 61   NaN
# Name: Country, Length: 62, dtype: float64

# %%
df
# Out:
#                Player  Mat  Inns  NOT_outs  Runs Hight_InnsScore    Ave  \
# 0    DG Bradman (AUS)   52    80        10  6996             334  99.94
# 1      HC Brook (ENG)   12    20         1  1181             186  62.15
# 2      AC Voges (AUS)   20    31         7  1485            269*  61.87
# 3     RG Pollock (SA)   23    41         4  2256             274  60.97
# 4     GA Headley (WI)   22    40         4  2190            270*  60.83
# ..                ...  ...   ...       ...   ...             ...    ...
# 57   KD Walters (AUS)   74   125        14  5357             250  48.26
# 58  GC Smith (ICC/SA)  117   205        13  9265             277  48.25
# 59  WH Ponsford (AUS)   29    48         4  2122             266  48.22
# 60    SJ McCabe (AUS)   39    62         5  2748             232  48.21
# 61   DR Jardine (ENG)   22    33         6  1296             127  48.00
#
#        BF     SR  100  50   0    4s  6s Rookie_Year Final_Year dopist  Country
# ...

# %%
df['Player']=df['Player'].str.split(pat='(').str[0]

# %%
df.head()
# Out:
#         Player  Mat  Inns  NOT_outs  Runs Hight_InnsScore    Ave     BF  \
# 0  DG Bradman    52    80        10  6996             334  99.94  9800+
# 1    HC Brook    12    20         1  1181             186  62.15   1287
# 2    AC Voges    20    31         7  1485            269*  61.87   2667
# 3  RG Pollock    23    41         4  2256             274  60.97  1707+
# 4  GA Headley    22    40         4  2190            270*  60.83   416+
#
#       SR  100  50  0   4s  6s Rookie_Year Final_Year dopist  Country
# 0   58.6   29  13  7  626   6        1928       1948   58.6      NaN
# 1  91.76    4   7  1  141  23        2022       2023  91.76      NaN
# 2  55.68    5   4  2  186   5        2015       2016  55.68      NaN
# 3  54.48    7  11  1  246  11        1963       1970  54.48      NaN
# 4     56   10   5  2  104   1        1930       1954     56      NaN

# %%
df
# Out:
#           Player  Mat  Inns  NOT_outs  Runs Hight_InnsScore    Ave     BF  \
# 0    DG Bradman    52    80        10  6996             334  99.94  9800+
# 1      HC Brook    12    20         1  1181             186  62.15   1287
# 2      AC Voges    20    31         7  1485            269*  61.87   2667
# 3    RG Pollock    23    41         4  2256             274  60.97  1707+
# 4    GA Headley    22    40         4  2190            270*  60.83   416+
# ..           ...  ...   ...       ...   ...             ...    ...    ...
# 57   KD Walters    74   125        14  5357             250  48.26  8662+
# 58     GC Smith   117   205        13  9265             277  48.25  15525
# 59  WH Ponsford    29    48         4  2122             266  48.22  3118+
# 60    SJ McCabe    39    62         5  2748             232  48.21  3217+
# 61   DR Jardine    22    33         6  1296             127  48.00  2110+
#
#        SR  100  50   0    4s  6s Rookie_Year Final_Year dopist  Country
# ...

# %%
df.dtypes
# Out:
# Player              object
# Mat                  int64
# Inns                 int64
# NOT_outs             int64
# Runs                 int64
# Hight_InnsScore     object
# Ave                float64
# BF                  object
# SR                  object
# 100                  int64
# 50                   int64
# 0                    int64
# 4s                   int64
# 6s                   int64
# Rookie_Year         object
# Final_Year          object
# dopist              object
# Country            float64
# dtype: object

# %%
df['Hight_InnsScore']=df['Hight_InnsScore'].str.split(pat='*').str[0]

# %%
df
# Out:
#           Player  Mat  Inns  NOT_outs  Runs Hight_InnsScore    Ave     BF  \
# 0    DG Bradman    52    80        10  6996             334  99.94  9800+
# 1      HC Brook    12    20         1  1181             186  62.15   1287
# 2      AC Voges    20    31         7  1485             269  61.87   2667
# 3    RG Pollock    23    41         4  2256             274  60.97  1707+
# 4    GA Headley    22    40         4  2190             270  60.83   416+
# ..           ...  ...   ...       ...   ...             ...    ...    ...
# 57   KD Walters    74   125        14  5357             250  48.26  8662+
# 58     GC Smith   117   205        13  9265             277  48.25  15525
# 59  WH Ponsford    29    48         4  2122             266  48.22  3118+
# 60    SJ McCabe    39    62         5  2748             232  48.21  3217+
# 61   DR Jardine    22    33         6  1296             127  48.00  2110+
#
#        SR  100  50   0    4s  6s Rookie_Year Final_Year dopist  Country
# ...

# %%
df['Hight_InnsScore']=df['Hight_InnsScore'].astype('int')

# %%
df.dtypes
# Out:
# Player              object
# Mat                  int64
# Inns                 int64
# NOT_outs             int64
# Runs                 int64
# Hight_InnsScore      int32
# Ave                float64
# BF                  object
# SR                  object
# 100                  int64
# 50                   int64
# 0                    int64
# 4s                   int64
# 6s                   int64
# Rookie_Year         object
# Final_Year          object
# dopist              object
# Country            float64
# dtype: object

# %%
df=df.astype({'Rookie_Year':'int','Final_Year':'int'})

# %%
df.dtypes
# Out:
# Player              object
# Mat                  int64
# Inns                 int64
# NOT_outs             int64
# Runs                 int64
# Hight_InnsScore      int32
# Ave                float64
# BF                  object
# SR                  object
# 100                  int64
# 50                   int64
# 0                    int64
# 4s                   int64
# 6s                   int64
# Rookie_Year          int32
# Final_Year           int32
# dopist              object
# Country            float64
# dtype: object

# %%
df.drop(['dopist'], axis=1)
# Out:
#           Player  Mat  Inns  NOT_outs  Runs  Hight_InnsScore    Ave     BF  \
# 0    DG Bradman    52    80        10  6996              334  99.94  9800+
# 1      HC Brook    12    20         1  1181              186  62.15   1287
# 2      AC Voges    20    31         7  1485              269  61.87   2667
# 3    RG Pollock    23    41         4  2256              274  60.97  1707+
# 4    GA Headley    22    40         4  2190              270  60.83   416+
# ..           ...  ...   ...       ...   ...              ...    ...    ...
# 57   KD Walters    74   125        14  5357              250  48.26  8662+
# 58     GC Smith   117   205        13  9265              277  48.25  15525
# 59  WH Ponsford    29    48         4  2122              266  48.22  3118+
# 60    SJ McCabe    39    62         5  2748              232  48.21  3217+
# 61   DR Jardine    22    33         6  1296              127  48.00  2110+
#
#        SR  100  50   0    4s  6s  Rookie_Year  Final_Year  Country
# ...

# %%
df['BF'].str.split(pat='+').str[0]
# Out:
# 0      9800
# 1      1287
# 2      2667
# 3      1707
# 4       416
#       ...
# 57     8662
# 58    15525
# 59     3118
# 60     3217
# 61     2110
# Name: BF, Length: 62, dtype: object

# %%
df
# Out:
#           Player  Mat  Inns  NOT_outs  Runs  Hight_InnsScore    Ave     BF  \
# 0    DG Bradman    52    80        10  6996              334  99.94  9800+
# 1      HC Brook    12    20         1  1181              186  62.15   1287
# 2      AC Voges    20    31         7  1485              269  61.87   2667
# 3    RG Pollock    23    41         4  2256              274  60.97  1707+
# 4    GA Headley    22    40         4  2190              270  60.83   416+
# ..           ...  ...   ...       ...   ...              ...    ...    ...
# 57   KD Walters    74   125        14  5357              250  48.26  8662+
# 58     GC Smith   117   205        13  9265              277  48.25  15525
# 59  WH Ponsford    29    48         4  2122              266  48.22  3118+
# 60    SJ McCabe    39    62         5  2748              232  48.21  3217+
# 61   DR Jardine    22    33         6  1296              127  48.00  2110+
#
# ...

# %%
df['BF']=df['BF'].str.split(pat='+').str[0]

# %%
df
# Out:
#           Player  Mat  Inns  NOT_outs  Runs  Hight_InnsScore    Ave     BF  \
# 0    DG Bradman    52    80        10  6996              334  99.94   9800
# 1      HC Brook    12    20         1  1181              186  62.15   1287
# 2      AC Voges    20    31         7  1485              269  61.87   2667
# 3    RG Pollock    23    41         4  2256              274  60.97   1707
# 4    GA Headley    22    40         4  2190              270  60.83    416
# ..           ...  ...   ...       ...   ...              ...    ...    ...
# 57   KD Walters    74   125        14  5357              250  48.26   8662
# 58     GC Smith   117   205        13  9265              277  48.25  15525
# 59  WH Ponsford    29    48         4  2122              266  48.22   3118
# 60    SJ McCabe    39    62         5  2748              232  48.21   3217
# 61   DR Jardine    22    33         6  1296              127  48.00   2110
#
# ...

# %%
df= df.drop(16,axis=0)

# %%
df= df.drop(56,axis=0)

# %%
df['BF']=df['BF'].str.split(pat='+').str[0]

# %%
df
# Out:
#                Player  Mat  Inns  NOT_outs   Runs  Hight_InnsScore    Ave  \
# 0         DG Bradman    52    80        10   6996              334  99.94
# 1           HC Brook    12    20         1   1181              186  62.15
# 2           AC Voges    20    31         7   1485              269  61.87
# 3         RG Pollock    23    41         4   2256              274  60.97
# 4         GA Headley    22    40         4   2190              270  60.83
# 5        H Sutcliffe    54    84         9   4555              194  60.73
# 6          E Paynter    20    31         5   1540              243  59.23
# 7      KF Barrington    82   131        15   6806              256  58.67
# 8          ED Weekes    48    81         5   4455              207  58.61
# 9         WR Hammond    85   140        16   7249              336  58.45
# 10         SPD Smith   106   189        24   9537              239  57.80
# 11         GS Sobers    93   160        21   8032              365  57.78
# ...
